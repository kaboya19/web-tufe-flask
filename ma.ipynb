# %%
import pandas as pd

ma=pd.read_excel("matuik.xls")

ma.columns=ma.iloc[1]
ma=ma.iloc[2:]
ma.columns=[                                                                                         "Tarih",
                                                                                             'TÜFE',
                  'İşlenmemiş gıda ürünleri, enerji, alkollü içkiler ve tütün ile altın hariç TÜFE',
       'Enerji, gıda ve alkolsüz içecekler, alkollü içkiler ile tütün ürünleri ve altın hariç TÜFE',
                                                                                                "",
                                                                                           'Enerji',
                                                                       'Gıda ve alkolsüz içecekler',
                                                                                  'İşlenmemiş gıda',
                                                                              'Taze meyve ve sebze',
                                                                            'Diğer işlenmemiş gıda',
                                                                                    'İşlenmiş gıda',
                                                                                'Ekmek ve tahıllar',
                                                                              'Diğer işlenmiş gıda',
                                                                       'Enerji ve gıda dışı mallar',
                                                                                     'Temel mallar',
                                                                                'Giyim ve ayakkabı',
                                                                   'Dayanıklı mallar (Altın hariç)',
                                                                               'Diğer temel mallar',
                                                                         'Alkollü içecekler, tütün',
                                                                                            'Altın',
                                                                                                "",
                                                                                             'Kira',
                                                                               'Lokanta ve oteller',
                                                                          'Ulaştırma hizmetleri(5)',
                                                                         'Haberleşme hizmetleri(5)',
                                                                                  'Diğer hizmetler']
ma=ma.set_index("Tarih")
ma
# Out:
#          TÜFE  \
# Tarih
# 2025-02  2.17
# 2025-03  2.48
# 2025-04   2.5
# 2025-05  1.96
# 2025-06  1.97
# 2025-07  2.64
# 2025-08  2.47
#
#         İşlenmemiş gıda ürünleri, enerji, alkollü içkiler ve tütün ile altın hariç TÜFE  \
# Tarih
# 2025-02                                               2.59
# 2025-03                                               1.82
# 2025-04                                               2.67
# 2025-05                                               2.06
# 2025-06                                               1.97
# 2025-07                                               2.25
# 2025-08                                                2.2
#
#         Enerji, gıda ve alkolsüz içecekler, alkollü içkiler ile tütün ürünleri ve altın hariç TÜFE  \
# Tarih
# 2025-02                                               2.13
# 2025-03                                                2.1
# 2025-04                                               2.81
# 2025-05                                                2.2
# 2025-06                                               2.19
# 2025-07                                               2.26
# 2025-08                                               1.84
#
#               Enerji Gıda ve alkolsüz içecekler İşlenmemiş gıda  \
# Tarih
# 2025-02  1.62   3.58                       1.95           -1.37
# 2025-03  2.32   0.03                       3.47            7.21
# 2025-04  2.35   4.32                       1.28            0.36
# 2025-05  1.68   2.15                       1.53             1.7
# 2025-06  1.49   2.27                       1.48             2.1
# 2025-07  2.38   7.35                       1.12           -0.15
# 2025-08  2.34   0.64                       4.44             5.2
#
#         Taze meyve ve sebze Diğer işlenmemiş gıda İşlenmiş gıda  ...  \
# Tarih                                                            ...
# 2025-02               -6.71                  2.38           4.7  ...
# 2025-03               15.01                  2.22          0.57  ...
# 2025-04               -1.06                  1.37          2.04  ...
# 2025-05                4.53                 -0.29          1.39  ...
# 2025-06                3.39                  1.14          0.97  ...
# 2025-07                -2.4                  1.55          2.18  ...
# 2025-08                6.37                  4.35          3.83  ...
#
#         Dayanıklı mallar (Altın hariç) Diğer temel mallar  \
# Tarih
# 2025-02                           1.11               1.26
# 2025-03                           1.63               2.09
# 2025-04                           3.43               2.38
# 2025-05                           2.73               1.49
# 2025-06                           1.24               1.59
# 2025-07                           1.57               2.02
# 2025-08                           0.73               1.01
#
#         Alkollü içecekler, tütün Altın        Kira Lokanta ve oteller  \
# Tarih
# 2025-02                    -0.01  4.78  3.37  5.28               2.35
# 2025-03                     9.96  1.33  2.81   4.2               2.25
# 2025-04                    -0.06  7.04  2.84  4.16               2.27
# 2025-05                     0.06  2.65  2.55  4.09               1.65
# 2025-06                     0.14  4.17  2.96  4.28               2.12
# 2025-07                     5.69  1.91  3.19  4.11               2.45
# 2025-08                     6.04  0.22  2.73  3.88               2.51
#
#         Ulaştırma hizmetleri(5) Haberleşme hizmetleri(5) Diğer hizmetler
# Tarih
# 2025-02                    3.87                     3.66            2.73
# 2025-03                    2.69                     0.55            2.87
# 2025-04                    2.34                     0.38            3.08
# 2025-05                    2.86                    -0.14            2.71
# 2025-06                    2.55                     1.48             3.1
# 2025-07                    1.83                     5.67            2.93
# 2025-08                    1.38                     1.65            2.68
#
# [7 rows x 25 columns]
